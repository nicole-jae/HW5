# %%
#imports

import requests as rq
import bs4
import pandas as pd
import plotly.express as px
import io
import numpy as np
import plotly.graph_objects as go

# %%
#reading in the data

url = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
#Need to set user agent because the default option wasn't working for me
headers = {
    'User-Agent': 'nolandr1 (nolandr1@jh.edu)'
}
page = rq.get(url, headers=headers)
## print out the first 100 characters just to see what it looks like
page.text[0 : 99]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-l'

# %%
#reading into bs4

bs4page = bs4.BeautifulSoup(page.text, 'html.parser')
tables = bs4page.find('table',{'class':"wikitable"})

gdp = pd.read_html(io.StringIO(str(tables)))

# %%
#reading into pandas

gdp = pd.read_html(io.StringIO(str(tables)))[0]
gdp.head()
# Out:
#   Country/Territory IMF (2026)[6] World Bank (2024)[7]  \
# 0             World     123584494            111326370
# 1     United States      31821293             28750956
# 2        China[n 1]      20650754             18743803
# 3           Germany       5328184              4685593
# 4             India       4505629              3909892
#
#   United Nations (2024)[8]
# 0                100834796
# 1                 29298000
# 2                 18743802
# 3                  4659929
# 4                  3952244

# %%
#Old Table with UN Region info

url = 'https://en.wikipedia.org/w/index.php?title=List_of_countries_by_GDP_(nominal)&oldid=1187446467'
headers = {
    'User-Agent': 'nolandr1 (nolandr1@jh.edu)'
}
page = rq.get(url, headers=headers)
## print out the first 100 characters just to see what it looks like
page.text[0 : 99]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-l'

# %%
#Finding the table in Old GDP

bs4page = bs4.BeautifulSoup(page.text, 'html.parser')
all_tables = pd.read_html(io.StringIO(page.text))
old_gdp = all_tables[2]

# Flatten the MultiIndex columns to a single level
old_gdp.columns = old_gdp.columns.get_level_values(1)

#dropping every column except UN region & Country/Territory
old_gdp = old_gdp[['Country/Territory', 'UN region']]
old_gdp.head()
# Out:
#   Country/Territory UN region
# 0             World         —
# 1     United States  Americas
# 2             China      Asia
# 3           Germany    Europe
# 4             Japan      Asia

# %%
#Merging the two dataframes together

merge_gdp = pd.merge(gdp, old_gdp, on='Country/Territory')
merge_gdp.head()
# Out:
#   Country/Territory IMF (2026)[6] World Bank (2024)[7]  \
# 0             World     123584494            111326370
# 1     United States      31821293             28750956
# 2           Germany       5328184              4685593
# 3             India       4505629              3909892
# 4             Japan       4463634              4027598
#
#   United Nations (2024)[8] UN region
# 0                100834796         —
# 1                 29298000  Americas
# 2                  4659929    Europe
# 3                  3952244      Asia
# 4                  4026211      Asia

# %%
#Creating the plot

fig = px.bar(merge_gdp, x='UN region', y='IMF (2026)[6]', color='Country/Territory')
fig.show()
fig.write_html('stacked_bar.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da063c14-7b2b-41f8-acd6-b0c693c47bdd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da063c14-7b2b-41f8-acd6-b0c693c47bdd")) {                    Plotly.newPlot(                        "da063c14-7b2b-41f8-acd6-b0c693c47bdd",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=World\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"World","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"World","offsetgroup":"World","orientation":"v","showlegend":true,"textposition":"auto","x":["—"],"xaxis":"x","y":["123584494"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=United States\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["Americas"],"xaxis":"x","y":["31821293"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Germany\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":["5328184"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=India\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":["4505629"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Japan\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":["4463634"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=United Kingdom\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United Kingdom","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"United Kingdom","offsetgroup":"United Kingdom","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":["4225639"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=France\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":["3558562"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Italy\u003cbr\u003eUN region=%{x}\u003cbr\u003eIMF (2026)[6]=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Italy","offsetgroup":"Italy","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":["2701544"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Russia\u003cbr\ ...

# %%
dat = pd.read_csv("https://raw.githubusercontent.com/smart-stats/ds4bio_book/main/book/assetts/kirby21AllLevels.csv").drop(['Unnamed: 0'], axis = 1)
dat.head()
# Out:
#                   rawid              roi  volume   min    max      mean  \
# 0  kirby127a_3_1_ax.img  Telencephalon_L  531111   0.0  374.0  128.3013
# 1  kirby127a_3_1_ax.img  Telencephalon_R  543404   0.0  300.0  135.0683
# 2  kirby127a_3_1_ax.img   Diencephalon_L    9683  15.0  295.0  193.5488
# 3  kirby127a_3_1_ax.img   Diencephalon_R    9678  10.0  335.0  193.7051
# 4  kirby127a_3_1_ax.img    Mesencephalon   10268  55.0  307.0  230.8583
#
#        std  type  level   id      icv      tbv
# 0  51.8593     1      1  127  1378295  1268519
# 1  53.6471     1      1  127  1378295  1268519
# 2  32.2733     1      1  127  1378295  1268519
# 3  32.7869     1      1  127  1378295  1268519
# 4  29.2249     1      1  127  1378295  1268519

# %%
dat = dat.assign(id_char = dat.id.astype(str))
fig = px.bar(dat, x = "id_char", y = "volume", color = "roi")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bea05bf3-ec21-4b1c-8b66-a9ad428f0d60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bea05bf3-ec21-4b1c-8b66-a9ad428f0d60")) {                    Plotly.newPlot(                        "bea05bf3-ec21-4b1c-8b66-a9ad428f0d60",                        [{"alignmentgroup":"True","hovertemplate":"roi=Telencephalon_L\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Telencephalon_L","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Telencephalon_L","offsetgroup":"Telencephalon_L","orientation":"v","showlegend":true,"textposition":"auto","x":["127","142","239","346","422","492","501","505","656","679","742","800","814","815","849","906","913","916","934","959"],"xaxis":"x","y":[531111,545603,483107,558849,509945,538936,506151,457862,551654,482556,483496,373246,526596,468915,516579,467063,486629,557758,468971,512967],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roi=Telencephalon_R\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Telencephalon_R","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Telencephalon_R","offsetgroup":"Telencephalon_R","orientation":"v","showlegend":true,"textposition":"auto","x":["127","142","239","346","422","492","501","505","656","679","742","800","814","815","849","906","913","916","934","959"],"xaxis":"x","y":[543404,552216,490805,568830,518902,541024,516742,461817,570542,490654,488470,380492,543440,473350,519582,470488,495646,572435,476112,519178],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roi=Diencephalon_L\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Diencephalon_L","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Diencephalon_L","offsetgroup":"Diencephalon_L","orientation":"v","showlegend":true,"textposition":"auto","x":["127","142","239","346","422","492","501","505","656","679","742","800","814","815","849","906","913","916","934","959"],"xaxis":"x","y":[9683,9156,8937,8828,9749,10023,9315,8120,9519,8996,9035,7066,9107,8992,9072,8801,10137,9552,7396,8634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roi=Diencephalon_R\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Diencephalon_R","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Diencephalon_R","offsetgroup":"Diencephalon_R","orientation":"v","showlegend":true,"textposition":"auto","x":["127","142","239","346","422","492","501","505","656","679","742","800","814","815","849","906","913","916","934","959"],"xaxis":"x","y":[9678,9071,9004,8933,9722,10142,9104,8126,9678,8990,8831,7396,9438,9092,8958,9054,9810,9846,7707,9143],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roi=Mesencephalon\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mesencephalon","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Mesencephalon","offsetgroup":"Mesencephalon","orientation":"v","showlegend":true,"textposition":"auto","x":["127","142","239","346","422","492","501","505","656","679","742","800","814","815","849","906","913","916","934","959"],"xaxis":"x","y":[10268,10516,9070,9788,12263,11734,10118,9098,12106,10979,10494,7286,10972,10499,10102,9564,11386,11360,8384,10470],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"roi=Metencephalon\u003cbr\u003eid_char=%{x}\u003cbr\u003evolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metencephalon","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name" ...

# %%
icv = dat.groupby(['id']).volume.sum().reset_index().rename(columns = {'volume' : 'icv'})
dat = pd.merge(dat, icv, on = 'id')
dat = dat.assign(comp = dat.volume / dat.icv)
dat.head()
# Out:
#                   rawid              roi  volume   min    max      mean  \
# 0  kirby127a_3_1_ax.img  Telencephalon_L  531111   0.0  374.0  128.3013
# 1  kirby127a_3_1_ax.img  Telencephalon_R  543404   0.0  300.0  135.0683
# 2  kirby127a_3_1_ax.img   Diencephalon_L    9683  15.0  295.0  193.5488
# 3  kirby127a_3_1_ax.img   Diencephalon_R    9678  10.0  335.0  193.7051
# 4  kirby127a_3_1_ax.img    Mesencephalon   10268  55.0  307.0  230.8583
#
#        std  type  level   id    icv_x      tbv id_char     icv_y       icv  \
# 0  51.8593     1      1  127  1378295  1268519     127  13783255  13783255
# 1  53.6471     1      1  127  1378295  1268519     127  13783255  13783255
# 2  32.2733     1      1  127  1378295  1268519     127  13783255  13783255
# 3  32.7869     1      1  127  1378295  1268519     127  13783255  13783255
# 4  29.2249     1      1  127  1378295  1268519     127  13783255  13783255
#
#        comp
# 0  0.038533
# 1  0.039425
# 2  0.000703
# 3  0.000702
# 4  0.000745

# %%
roi_mean = dat.drop(["id", "id_char", "icv", "rawid"], axis = 1).groupby(["roi"]).mean().reset_index()
fig = px.bar(roi_mean, x = "roi", y = "comp")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="76614408-2a27-4410-82f4-9f7f18b00518" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76614408-2a27-4410-82f4-9f7f18b00518")) {                    Plotly.newPlot(                        "76614408-2a27-4410-82f4-9f7f18b00518",                        [{"alignmentgroup":"True","hovertemplate":"roi=%{x}\u003cbr\u003ecomp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["ACR_L","ACR_R","AGWM_L","AGWM_R","AG_L","AG_R","ALIC_L","ALIC_R","A_L","A_R","Amyg_L","Amyg_R","AnteriorLateralVentricle_L","AnteriorLateralVentricle_R","AnteriorWM_L","AnteriorWM_R","BCC_L","BCC_R","BasalForebrain_L","BasalForebrain_R","BasalGang_L","BasalGang_R","Brainstem","Brainstem_L","Brainstem_R","CGC_L","CGC_R","CGH_L","CGH_R","CP_L","CP_R","CSF","CST_L","CST_R","Caud_L","Caud_R","Caudate_tail_L","Caudate_tail_R","CentralSul_L","CentralSul_R","Cerebellum","CerebellumGM_L","CerebellumGM_R","CerebellumWM_L","CerebellumWM_R","Cerebellum_L","Cerebellum_R","CerebralCortex_L","CerebralCortex_R","CerebralNucli_L","CerebralNucli_R","Chroid_LVetc_L","Chroid_LVetc_R","CinguSul_L","CinguSul_R","Cingulate_L","Cingulate_R","Cl_L","Cl_R","CorpusCallosum_L","CorpusCallosum_R","CuWM_L","CuWM_R","Cu_L","Cu_R","Diencephalon_L","Diencephalon_R","ECCL_L","ECCL_R","EC_L","EC_R","ENT_L","ENT_R","Fimbria_L","Fimbria_R","FrontSul_L","FrontSul_R","Frontal_L","Frontal_R","FuG_L","FuG_R","FuWM_L","FuWM_R","Fu_L","Fu_R","Fx\u002fST_L","Fx\u002fST_R","Fx_L","Fx_R","GCC_L","GCC_R","GP_L","GP_R","Hemisphere_L","Hemisphere_R","Hippo_L","Hippo_R","HypoThalamus_L","HypoThalamus_R","ICP_L","ICP_R","ICP_cb_L","ICP_cb_R","IFG_L","IFG_R","IFG_opercularis_L","IFG_opercularis_R","IFG_orbitalis_L","IFG_orbitalis_R","IFG_triangularis_L","IFG_triangularis_R","IFO_L","IFO_R","IFWM_opercularis_L","IFWM_opercularis_R","IFWM_orbitalis_L","IFWM_orbitalis_R","IFWM_triangularis_L","IFWM_triangularis_R","IF_opercularis_L","IF_opercularis_R","IF_orbitalis_L","IF_orbitalis_R","IF_triangularis_L","IF_triangularis_R","III_ventricle","IOG_L","IOG_R","IOWM_L","IOWM_R","IO_L","IO_R","ITG_L","ITG_R","ITWM_L","ITWM_R","IT_L","IT_R","IV_ventricle","InferiorLateralVentricle_L","InferiorLateralVentricle_R","InferiorWM_L","InferiorWM_R","Insula_L","Insula_R","InternalCapsule_L","InternalCapsule_R","LFOG_L","LFOG_R","LFOWM_L","LFOWM_R","LFO_L","LFO_R","LGWM_L","LGWM_R","LG_L","LG_R","LV_Frontal_L","LV_Frontal_R","LV_Inferior_L","LV_Inferior_R","LV_Occipital_L","LV_Occipital_R","LV_atrium_L","LV_atrium_R","LV_body_L","LV_body_R","LateralVentricle_L","LateralVentricle_R","LimbicWM_L","LimbicWM_R","Limbic_L","Limbic_R","MCP_L","MCP_R","MCP_cb_L","MCP_cb_R","MFG_DPFC_L","MFG_DPFC_R","MFG_L","MFG_R","MFOG_L","MFOG_R","MFOWM_L","MFOWM_R","MFO_L","MFO_R","MFWM_DPFC_L","MFWM_DPFC_R","MFWM_L","MFWM_R","MF_DPFC_L","MF_DPFC_R","MF_L","MF_R","ML_L","ML_R","MOG_L","MOG_R","MOWM_L","MOWM_R","MO_L","MO_R","MTG_L","MTG_L_pole","MTG_R","MTG_R_pole","MTWM_L","MTWM_L_pole","MTWM_R","MTWM_R_pole","MT_L","MT_L_pole","MT_R","MT_R_pole","Mammillary_L","Mammillary_R","Medulla_L","Medulla_R","Mesencephalon","Mesencephalon_L","Mesencephalon_R","Metencephalon","Metencephalon_L","Metencephalon_R","Midbrain_L","Midbrain_R","Myelencephalon","Myelencephalon_L","Myelencephalon_R","NucAccumbens_L","NucAccumbens_R","OG_L","OG_R","Occipital_L","Occipital_R","OcciptSul_L","OcciptSul_R","PCCWM_L","PCCWM_R","PCC_L","PCC_R","PCR_L","PCR_R","PCT_L","PCT_R","PHG_L","PHG_R","PLIC_L","PLIC_R","PTR_L","PTR_R","PVA_anterior_L","PVA_anterior_R","PVA_posterior_L","PVA_posterior_R","PVWa_L","PVWa_R","PVWl_ ...

# %%
url = "https://raw.githubusercontent.com/bcaffo/MRIcloudT1volumetrics/master/inst/extdata/multilevel_lookup_table.txt"
multilevel_lookup = pd.read_csv(url, sep = "\t").drop(['Level5'], axis = 1)
multilevel_lookup = multilevel_lookup.rename(columns = {
    "modify"   : "roi",
    "modify.1" : "level4",
    "modify.2" : "level3",
    "modify.3" : "level2",
    "modify.4" : "level1"})
multilevel_lookup = multilevel_lookup[['roi', 'level4', 'level3', 'level2', 'level1']]
multilevel_lookup.head()
# Out:
#           roi level4     level3            level2           level1
# 0       SFG_L  SFG_L  Frontal_L  CerebralCortex_L  Telencephalon_L
# 1       SFG_R  SFG_R  Frontal_R  CerebralCortex_R  Telencephalon_R
# 2   SFG_PFC_L  SFG_L  Frontal_L  CerebralCortex_L  Telencephalon_L
# 3   SFG_PFC_R  SFG_R  Frontal_R  CerebralCortex_R  Telencephalon_R
# 4  SFG_pole_L  SFG_L  Frontal_L  CerebralCortex_L  Telencephalon_L

# %%
#Displaying levels for Type = 1 data

id = 127
subjectData = pd.read_csv("https://raw.githubusercontent.com/smart-stats/ds4bio_book/main/book/assetts/kirby21AllLevels.csv")
subjectData = subjectData.loc[(subjectData.type == 1) & (subjectData.id == id)]
subjectData = subjectData[['roi', 'volume']]

subjectData = pd.merge(subjectData, multilevel_lookup, on = "roi")
subjectData = subjectData.assign(icv = "ICV")
subjectData = subjectData.assign(comp = subjectData.volume / np.sum(subjectData.volume))
subjectData.head()
# Out:
#                 roi  volume                                        level4  \
# 0               CSF  109776  xxxx xxxx xxxx xxxx xxxx xxxx xxxx xxxx xxxx
# 1        Thalamus_L    6342                                    Thalamus_L
# 2        Thalamus_R    6372                                    Thalamus_R
# 3  BasalForebrain_L    3341                              BasalForebrain_L
# 4  BasalForebrain_L    3341                              BasalForebrain_L
#
#              level3            level2          level1  icv      comp
# 0               NaN               NaN             NaN  ICV  0.047225
# 1        Thalamus_L        Thalamus_L  Diencephalon_L  ICV  0.002728
# 2        Thalamus_R        Thalamus_R  Diencephalon_R  ICV  0.002741
# 3  BasalForebrain_L  BasalForebrain_L  Diencephalon_L  ICV  0.001437
# 4  BasalForebrain_L  BasalForebrain_L  Diencephalon_L  ICV  0.001437

# %%
data = ['icv', 'level1', 'level2', 'level3', 'level4', 'roi']

all_nodes = []
for level in data:
    all_nodes.extend(subjectData_cleaned[level].unique())

all_nodes = [node for node in all_nodes if node != '']
all_nodes = sorted(list(set(all_nodes)))
node_to_index = {node: i for i, node in enumerate(all_nodes)}


source_indices = []
target_indices = []
link_values = []


for index, row in subjectData_cleaned.iterrows():
    current_value = row['comp']


    for i in range(len(data) - 1):
        source_level = data[i]
        target_level = data[i+1]

        source_node = row[source_level]
        target_node = row[target_level]


        if source_node != '' and target_node != '':
            source_indices.append(node_to_index[source_node])
            target_indices.append(node_to_index[target_node])
            link_values.append(current_value)


fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=all_nodes,
        color="blue"
    ),
    link=dict(
        source=source_indices,
        target=target_indices,
        value=link_values,
    )
)])


fig.update_layout(title_text=f"Sankey Diagram", font_size=10)
fig.show()
fig.write_html('sankey.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8954ef12-6af6-4088-b0c3-9213ff74b4d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8954ef12-6af6-4088-b0c3-9213ff74b4d6")) {                    Plotly.newPlot(                        "8954ef12-6af6-4088-b0c3-9213ff74b4d6",                        [{"link":{"source":[93,59,331,331,331,93,60,332,332,332,93,59,16,16,16,93,59,16,16,16,93,60,17,17,17,93,60,17,17,17,93,325,41,124,124,93,326,42,125,125,93,59,331,331,331,93,60,332,332,332,93,59,16,16,16,93,59,16,16,16,93,60,17,17,17,93,60,17,17,17,93,187,188,245,245,93,187,189,246,246,93,192,193,182,182,93,192,194,183,183,93,26,333,110,110,93,26,315,69,69,93,26,316,70,70,93,26,315,33,33,93,26,316,34,34,93,26,315,227,227,93,26,316,228,228,93,26,315,47,47,93,26,316,48,48,93,26,315,201,201,93,26,316,202,202,93,26,315,327,327,93,26,316,328,328,93,26,333,119,119,93,325,41,71,275,93,326,42,72,278,93,325,41,71,156,93,326,42,72,157,93,325,41,71,263,93,326,42,72,264,93,325,41,229,241,93,326,42,230,242,93,325,41,71,251,93,326,42,72,252,93,325,41,229,299,93,326,42,230,300,93,325,41,229,291,93,326,42,230,292,93,325,41,229,4,93,326,42,230,5,93,325,41,229,257,93,326,42,230,258,93,325,41,329,305,93,326,42,330,307,93,325,41,329,172,93,326,42,330,174,93,325,41,329,115,93,326,42,330,116,93,325,41,329,73,93,326,42,330,74,93,325,41,199,295,93,326,42,200,296,93,325,41,199,168,93,326,42,200,169,93,325,41,199,111,93,326,42,200,112,93,325,41,199,57,93,326,42,200,58,93,325,41,199,132,93,326,42,200,133,93,325,41,124,124,93,326,42,125,125,93,325,43,148,8,93,326,44,149,9,93,325,41,148,85,93,326,42,149,86,93,325,43,18,29,93,326,44,19,30,93,325,43,18,259,93,326,44,19,260,93,325,43,18,83,93,326,44,19,84,93,59,331,331,331,93,60,332,332,332,93,59,16,16,16,93,59,16,16,16,93,60,17,17,17,93,60,17,17,17,93,187,188,245,245,93,187,189,246,246,93,192,193,182,182,93,192,194,183,183,93,325,335,53,81,93,326,336,54,82,93,325,335,53,14,93,326,336,54,15,93,325,335,53,269,93,326,336,54,270,93,325,335,122,6,93,326,336,123,7,93,325,335,122,213,93,326,336,123,214,93,325,335,146,20,93,326,336,147,21,93,325,335,146,22,93,326,336,147,23,93,325,335,146,77,93,326,336,147,78,93,325,335,146,79,93,326,336,147,80,93,26,333,110,110,93,187,189,40,38,93,187,188,39,37,93,26,315,69,69,93,26,316,70,70,93,26,315,33,33,93,26,316,34,34,93,26,315,323,317,93,26,316,324,318,93,26,315,323,321,93,26,316,324,322,93,26,315,323,319,93,26,316,324,320,93,26,315,227,227,93,26,316,228,228,93,26,315,47,47,93,26,316,48,48,93,26,315,201,201,93,26,316,202,202,93,26,315,327,327,93,26,316,328,328,93,325,43,18,31,93,326,44,19,32,93,26,333,119,119,93,325,41,71,275,93,326,42,72,278,93,325,41,71,275,93,326,42,72,278,93,325,41,71,275,93,326,42,72,278,93,325,41,71,156,93,326,42,72,157,93,325,41,71,156,93,326,42,72,157,93,325,41,71,94,93,326,42,72,95,93,325,41,71,94,93,326,42,72,95,93,325,41,71,94,93,326,42,72,95,93,325,41,71,197,93,326,42,72,198,93,325,41,71,197,93,326,42,72,198,93,325,41,71,263,93,326,42,72,264,93,325,41,229,241,93,326,42,230,242,93,325,41,71,251,93,326,42,72,252,93,325,41,229,299,93,326,42,230,300,93,325,41,229,291,93,326,42,230,292,93,325,41,229,4,93,326,42,230,5,93,325,41,229,257,93,326,42,230,258,93,325,41,329,305,93,326,42,330,307,93,325,41,329,305,93,326,42,330,307,93,325,41,329,172,93,326,42,330,174,93,325,41,329,172,93,326,42,330,174,93,325,41,329,115,93,326,42,330,116,93,325,41,148,148,93,326,42,149,149,93,325,41,148,148,93,326,42,149,149,93,325,41,329,73,93,326,42,330,74,93,325,41,199,295,93,326,42,200,296,93,325,41,199,168,93,326,42,200,169,93,325,41,199,111,93,326,42,200,112,93,325,41,199,57,93,326,42,200,58,93,325,41,199,132,93,326,42,200,133,93,325,41,148,49,93,326,42,149,50,93,325,41,148,49,93,326,42,149,50,93,325,41,148,49,93,326,4 ...
